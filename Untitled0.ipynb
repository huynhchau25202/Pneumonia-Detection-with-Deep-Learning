# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/chest_xray'

# %% [markdown]
# #Tạo ImageDataGenerator để load ảnh

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 150
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    data_dir + '/train',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    data_dir + '/val',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    data_dir + '/test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# #Kiểm tra ảnh đầu vào

# %%
import matplotlib.pyplot as plt

x_batch, y_batch = next(train_generator)

plt.figure(figsize=(10, 6))
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(x_batch[i])
    plt.title("PNEUMONIA" if y_batch[i] == 1 else "NORMAL")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Khởi tạo mô hình CNN (Keras)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# #Compile mô hình

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #Huấn luyện mô hình

# %%
EPOCHS = 30

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)
# Out:
# Epoch 1/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 89s 523ms/step - accuracy: 0.7553 - loss: 0.5498 - val_accuracy: 0.6250 - val_loss: 0.8271
# Epoch 2/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 518ms/step - accuracy: 0.9084 - loss: 0.2369 - val_accuracy: 0.6875 - val_loss: 0.8972
# Epoch 3/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 86s 526ms/step - accuracy: 0.9195 - loss: 0.2123 - val_accuracy: 0.8125 - val_loss: 0.4065
# Epoch 4/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 512ms/step - accuracy: 0.9277 - loss: 0.1890 - val_accuracy: 0.7500 - val_loss: 0.4861
# Epoch 5/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 511ms/step - accuracy: 0.9412 - loss: 0.1608 - val_accuracy: 0.9375 - val_loss: 0.3066
# Epoch 6/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 508ms/step - accuracy: 0.9432 - loss: 0.1492 - val_accuracy: 0.7500 - val_loss: 0.5577
# Epoch 7/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 511ms/step - accuracy: 0.9500 - loss: 0.1441 - val_accuracy: 0.7500 - val_loss: 0.5288
# Epoch 8/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 86s 527ms/step - accuracy: 0.9499 - loss: 0.1390 - val_accuracy: 0.6250 - val_loss: 0.9036
# Epoch 9/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 523ms/step - accuracy: 0.9498 - loss: 0.1313 - val_accuracy: 0.7500 - val_loss: 0.6203
# Epoch 10/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 81s 499ms/step - accuracy: 0.9507 - loss: 0.1313 - val_accuracy: 0.6875 - val_loss: 0.6258
# Epoch 11/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 80s 493ms/step - accuracy: 0.9482 - loss: 0.1215 - val_accuracy: 0.6875 - val_loss: 0.5481
# Epoch 12/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 81s 497ms/step - accuracy: 0.9534 - loss: 0.1150 - val_accuracy: 0.6875 - val_loss: 0.7608
# Epoch 13/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 514ms/step - accuracy: 0.9573 - loss: 0.1108 - val_accuracy: 0.6875 - val_loss: 1.1734
# Epoch 14/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 86s 530ms/step - accuracy: 0.9608 - loss: 0.1102 - val_accuracy: 0.7500 - val_loss: 0.5125
# Epoch 15/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 85s 519ms/step - accuracy: 0.9639 - loss: 0.1122 - val_accuracy: 0.6250 - val_loss: 0.8164
# Epoch 16/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - accuracy: 0.9615 - loss: 0.1084 - val_accuracy: 0.7500 - val_loss: 0.8605
# Epoch 17/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 509ms/step - accuracy: 0.9636 - loss: 0.0956 - val_accuracy: 0.6875 - val_loss: 1.1096
# Epoch 18/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 507ms/step - accuracy: 0.9550 - loss: 0.1178 - val_accuracy: 0.7500 - val_loss: 0.5845
# Epoch 19/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - accuracy: 0.9580 - loss: 0.1153 - val_accuracy: 0.6875 - val_loss: 0.8854
# Epoch 20/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 507ms/step - accuracy: 0.9700 - loss: 0.0885 - val_accuracy: 0.7500 - val_loss: 0.5371
# Epoch 21/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 84s 519ms/step - accuracy: 0.9674 - loss: 0.0891 - val_accuracy: 0.6875 - val_loss: 0.8934
# Epoch 22/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 510ms/step - accuracy: 0.9612 - loss: 0.1104 - val_accuracy: 0.6875 - val_loss: 0.8238
# Epoch 23/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 142s 509ms/step - accuracy: 0.9666 - loss: 0.0966 - val_accuracy: 0.7500 - val_loss: 0.6781
# Epoch 24/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 508ms/step - accuracy: 0.9650 - loss: 0.0972 - val_accuracy: 0.8125 - val_loss: 0.4156
# Epoch 25/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 507ms/step - accuracy: 0.9629 - loss: 0.0954 - val_accuracy: 0.6875 - val_loss: 0.8429
# Epoch 26/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 504ms/step - accuracy: 0.9705 - loss: 0.0818 - val_accuracy: 0.6875 - val_loss: 0.5895
# Epoch 27/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 500ms/step - accuracy: 0.9687 - loss: 0.0849 - val_accuracy: 0.6875 - val_loss: 0.7874
# Epoch 28/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 506ms/step - accuracy: 0.9632 - loss: 0.1019 - val_accuracy: 0.6875 - val_loss: 0.6008
# Epoch 29/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 499ms/step - accuracy: 0.9731 - loss: 0.0857 - val_accuracy: 0.8125 - val_loss: 0.3695
# Epoch 30/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 81s 495ms/step - accuracy: 0.9681 - loss: 0.0795 - val_accuracy: 0.8125 - val_loss: 0.3039

# %% [markdown]
# #Vẽ biểu đồ Accuracy và Loss

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(acc, label='Train Accuracy')
plt.plot(val_acc, label='Val Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.legend()
plt.title('Loss')

plt.show()

# %% [markdown]
# #Đánh giá mô hình với tập test

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f" Độ chính xác trên tập test: {test_acc*100:.2f}%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 213s 11s/step - accuracy: 0.7836 - loss: 0.9023
#  Độ chính xác trên tập test: 86.22%

# %% [markdown]
# #Lưu vào mô hình

# %%
model.save('/content/drive/MyDrive/pneumonia_cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
